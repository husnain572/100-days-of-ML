# %%
import pandas as pd
import requests
import time

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=c1d1510795af4e273f3a2ebdc170d25a&language=en-US&page=1')

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.shape
# Out:
# (20, 7)

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
  response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=c1d1510795af4e273f3a2ebdc170d25a&language=en-US&page={}'.format(i))

  temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     44.9982
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     31.7068
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     22.6057
# 3  The true story of how businessman Oskar Schind...   1993-12-15     21.1296
# 4  The defense and the prosecution have rested an...   1957-04-10     17.2332
#
#    vote_average  vote_count
# 0         8.717       30011
# 1         8.700       22669
# 2         8.573       13727
# 3         8.567       17250
# 4         8.556        9849

# %%
df.to_csv('popular_movies.csv')
